# %% [markdown]
# 참고: https://skyjwoo.tistory.com/entry/%EC%9E%90%EC%97%B0%EC%96%B4-%EC%B2%98%EB%A6%AC-EDAExploratory-Data-Analysis

# %% [markdown]
# # Chatbot dataset(songys) EDA

# %% [markdown]
# ---
# ## 데이터 및 패키지 로드

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib as mpl
import seaborn as sns

font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')


# 유니코드 깨짐현상 해결
mpl.rcParams['axes.unicode_minus'] = False

# 나눔고딕 폰트 적용
plt.rcParams["font.family"] = 'NanumGothic'

# %%
csvdataset = pd.read_csv("kor_chatbot.csv")
csvdataset
# Out:
#                              Q                         A  label
# 0                       12시 땡!                하루가 또 가네요.      0
# 1                  1지망 학교 떨어졌어                 위로해 드립니다.      0
# 2                 3박4일 놀러가고 싶다               여행은 언제나 좋죠.      0
# 3              3박4일 정도 놀러가고 싶다               여행은 언제나 좋죠.      0
# 4                      PPL 심하네                눈살이 찌푸려지죠.      0
# ...                        ...                       ...    ...
# 11818           훔쳐보는 것도 눈치 보임.        티가 나니까 눈치가 보이는 거죠!      2
# 11819           훔쳐보는 것도 눈치 보임.             훔쳐보는 거 티나나봐요.      2
# 11820              흑기사 해주는 짝남.                    설렜겠어요.      2
# 11821  힘든 연애 좋은 연애라는게 무슨 차이일까?  잘 헤어질 수 있는 사이 여부인 거 같아요.      2
# 11822               힘들어서 결혼할까봐        도피성 결혼은 하지 않길 바라요.      2
#
# [11823 rows x 3 columns]

# %%
# check null

csvdataset.isnull().sum()
# Out:
# Q        0
# A        0
# label    0
# dtype: int64

# %%
# 필요 패키지

import torch
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer


class ChatbotDataset(Dataset):
    def __init__(self, path: str):
        self.data = pd.read_csv(path)
        self.kogpt2_tokenizer = AutoTokenizer.from_pretrained('skt/kogpt2-base-v2')
        self.kobert_tokenizer = AutoTokenizer.from_pretrained('monologg/kobert')

    def __len__(self):
        return len(self.data["label"])

    def __getitem__(self, idx: int) -> tuple:
        return (self.data["Q"][idx], self.data["A"][idx], self.data["label"][idx])

# %% [markdown]
# ## 전처리

# %%
# EDA preprocessing

dataset = ChatbotDataset("kor_chatbot.csv")
dl = DataLoader(dataset, shuffle=True)

kogpt2_tok_lens_q, kogpt2_tok_lens_a = [], []
kobert_tok_lens_q, kobert_tok_lens_a = [], []
kogpt2_toks_q, kogpt2_toks_a = [], []
kobert_toks_q, kobert_toks_a = [], []
labels = []
for (q, a, label) in dl:
    kogpt2_tok_lens_q.append(len(dataset.kogpt2_tokenizer.tokenize(q[0])))
    kogpt2_tok_lens_a.append(len(dataset.kogpt2_tokenizer.tokenize(a[0])))
    kobert_tok_lens_q.append(len(dataset.kobert_tokenizer.tokenize(q[0])))
    kobert_tok_lens_a.append(len(dataset.kobert_tokenizer.tokenize(a[0])))
    labels.append(label)
    kogpt2_toks_q.extend(dataset.kogpt2_tokenizer.tokenize(q[0]))
    kogpt2_toks_a.extend(dataset.kogpt2_tokenizer.tokenize(a[0]))
    kobert_toks_q.extend(dataset.kobert_tokenizer.tokenize(q[0]))
    kobert_toks_a.extend(dataset.kobert_tokenizer.tokenize(a[0]))
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
print("KoGPT2 Question 전체 토큰 수", len(set(kogpt2_toks_q)))
print("KoGPT2 Question 토큰 수 평균", np.mean(kogpt2_tok_lens_q))
print("KoGPT2 Answer 전체 토큰 수", len(set(kogpt2_toks_a)))
print("KoGPT2 Answer 토큰 수 평균", np.mean(kogpt2_tok_lens_a))

print("KoBERT Question 전체 토큰 수", len(set(kobert_toks_q)))
print("KoBERT Question 토큰 수 평균", np.mean(kobert_tok_lens_q))
print("KoBERT Answer 전체 토큰 수", len(set(kobert_toks_a)))
print("KoBERT Answer 토큰 수 평균", np.mean(kobert_tok_lens_a))
# Out:
# KoGPT2 Question 전체 토큰 수 6034
# KoGPT2 Question 토큰 수 평균 6.729510276579548
# KoGPT2 Answer 전체 토큰 수 5252
# KoGPT2 Answer 토큰 수 평균 7.473568468239871
# KoBERT Question 전체 토큰 수 536
# KoBERT Question 토큰 수 평균 3.945868222955257
# KoBERT Answer 전체 토큰 수 363
# KoBERT Answer 토큰 수 평균 4.718091854859173

# %% [markdown]
# ## Question / Answer 토큰 빈도 분석

# %%
ax = csvdataset["Q"].str.len().hist()
ax.set_title("Question 단순 글자 수 빈도")
ax.set_xlabel("글자 수")
ax.set_ylabel("빈도")
# Out:
# Text(0, 0.5, '빈도')

# %%
ax = csvdataset["A"].str.len().hist()
ax.set_title("Answer 단순 글자 수 빈도")
ax.set_xlabel("글자 수")
ax.set_ylabel("빈도")
# Out:
# Text(0, 0.5, '빈도')

# %%
ax = pd.Series(kogpt2_tok_lens_q).hist()
ax.set_title("Question 토큰 수 빈도(KoGPT2)")
ax.set_xlabel("토큰 수")
ax.set_ylabel("빈도")
# Out:
# Text(0, 0.5, '빈도')

# %%
ax = pd.Series(kogpt2_tok_lens_a).hist()
ax.set_title("Answer 토큰 수 빈도(KoGPT2)")
ax.set_xlabel("토큰 수")
ax.set_ylabel("빈도")
# Out:
# Text(0, 0.5, '빈도')

# %%
ax = pd.Series(kobert_tok_lens_q).hist()
ax.set_title("Question 토큰 수 빈도(KoBERT)")
ax.set_xlabel("토큰 수")
ax.set_ylabel("빈도")
# Out:
# Text(0, 0.5, '빈도')

# %%
ax = pd.Series(kobert_tok_lens_a).hist()
ax.set_title("Answer 토큰 수 빈도(KoBERT)")
ax.set_xlabel("토큰 수")
ax.set_ylabel("빈도")
# Out:
# Text(0, 0.5, '빈도')

# %% [markdown]
# ## Question / Answer 명사 빈도 분석

# %%
from konlpy.tag import Mecab
import collections

mecab = Mecab()

# %%
q_noun, a_noun = [], []
for (q, a, label) in dl:
    q_noun += mecab.nouns(q[0])
    a_noun += mecab.nouns(a[0])

q_count = collections.Counter(q_noun)
q_most = q_count.most_common()
a_count = collections.Counter(a_noun)
a_most = a_count.most_common()

q_noun2, a_noun2 = [], []
for (q, a, label) in dl:
    for n in mecab.nouns(q[0]):
        if len(n) > 1:
            q_noun2.append(n)
    for m in mecab.nouns(a[0]):
        if len(m) > 1:
            a_noun2.append(m)

q_count2 = collections.Counter(q_noun2)
q_most2 = q_count2.most_common()
a_count2 = collections.Counter(a_noun2)
a_most2 = a_count2.most_common()

# %%
x, y = [], []
for word, count in q_most[:50]:
    x.append(word)
    y.append(count)
    
plt.figure(figsize=(10,10))
plt.title("Question 명사 빈도")
ax = sns.barplot(x=y, y=x)
ax.set(xlabel = '빈도 수', ylabel = '명사')
# Out:
# [Text(0.5, 0, '빈도 수'), Text(0, 0.5, '명사')]

# %%
x, y = [], []
for word, count in a_most[:50]:
    x.append(word)
    y.append(count)
    
plt.figure(figsize=(10,10))
plt.title("Answer 명사 빈도")
ax = sns.barplot(x=y, y=x)
ax.set(xlabel = '빈도 수', ylabel = '명사')
# Out:
# [Text(0.5, 0, '빈도 수'), Text(0, 0.5, '명사')]

# %% [markdown]
# ### 2글자 이상 명사

# %%
x, y = [], []
for word, count in q_most2[:50]:
    x.append(word)
    y.append(count)
    
plt.figure(figsize=(10,10))
plt.title("Question 명사 빈도(2자 이상)")
ax = sns.barplot(x=y, y=x)
ax.set(xlabel = '빈도 수', ylabel = '명사')
# Out:
# [Text(0.5, 0, '빈도 수'), Text(0, 0.5, '명사')]

# %%
x, y = [], []
for word, count in a_most2[:50]:
    x.append(word)
    y.append(count)
    
plt.figure(figsize=(10,10))
plt.title("Answer 명사 빈도(2자 이상)")
ax = sns.barplot(x=y, y=x)
ax.set(xlabel = '빈도 수', ylabel = '명사')
# Out:
# [Text(0.5, 0, '빈도 수'), Text(0, 0.5, '명사')]

# %% [markdown]
# ## Question / Answer 형태소 빈도

# %%
q_tags, a_tags = [], []
for (q, a, label) in dl:
    q_temp = mecab.pos(q[0])
    a_temp = mecab.pos(a[0])
    for q2 in q_temp:
        q_tags.append(q2[1])
    for a2 in a_temp:
        a_tags.append(a2[1])

q_count3 = collections.Counter(q_tags)
a_count3 = collections.Counter(a_tags)

# %%
x, y = list(map(list, zip(*q_count3.most_common(10))))
ax = sns.barplot(x=y, y=x)
ax.set(title = 'Question 형태소 빈도', xlabel = '빈도 수', ylabel = '형태소')
# Out:
# [Text(0.5, 1.0, 'Question 형태소 빈도'), Text(0.5, 0, '빈도 수'), Text(0, 0.5, '형태소')]

# %%
x, y = list(map(list, zip(*a_count3.most_common(10))))
ax = sns.barplot(x=y, y=x)
ax.set(title = 'Answer 형태소 빈도', xlabel = '빈도 수', ylabel = '형태소')
# Out:
# [Text(0.5, 1.0, 'Answer 형태소 빈도'), Text(0.5, 0, '빈도 수'), Text(0, 0.5, '형태소')]

# %% [markdown]
# ## Question / Answer N-gram 통계

# %%
from sklearn.feature_extraction.text import CountVectorizer

q_morphs, a_morphs = [], []
for (q, a, label) in dl:
    q_morphs.append(' '.join(mecab.morphs(q[0])))
    a_morphs.append(' '.join(mecab.morphs(a[0])))

def get_top_ngram(morphs, n=None):
    vec = CountVectorizer(ngram_range=(n, n)).fit(morphs)
    bag_of_words = vec.transform(morphs)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:20]

# %%
top_n_bigrams = get_top_ngram(q_morphs, 2)
x, y = map(list, zip(*top_n_bigrams))
ax = sns.barplot(x=y, y=x)
ax.set(xlabel='빈도 수', ylabel='2gram 형태소', title='Question 2-gram 통계(형태소)')
# Out:
# [Text(0.5, 0, '빈도 수'),
#  Text(0, 0.5, '2gram 형태소'),
#  Text(0.5, 1.0, 'Question 2-gram 통계(형태소)')]

# %%
top_n_bigrams = get_top_ngram(a_morphs, 2)
x, y = map(list, zip(*top_n_bigrams))
ax = sns.barplot(x=y, y=x)
ax.set(xlabel='빈도 수', ylabel='2gram 형태소', title='Answer 2-gram 통계(형태소)')
# Out:
# [Text(0.5, 0, '빈도 수'),
#  Text(0, 0.5, '2gram 형태소'),
#  Text(0.5, 1.0, 'Answer 2-gram 통계(형태소)')]

# %%
top_n_bigrams = get_top_ngram(q_morphs, 3)
x, y = map(list, zip(*top_n_bigrams))
ax = sns.barplot(x=y, y=x)
ax.set(xlabel='빈도 수', ylabel='3gram 형태소', title='Question 3-gram 통계(형태소)')
# Out:
# [Text(0.5, 0, '빈도 수'),
#  Text(0, 0.5, '3gram 형태소'),
#  Text(0.5, 1.0, 'Question 3-gram 통계(형태소)')]

# %%
top_n_bigrams = get_top_ngram(a_morphs, 3)
x, y = map(list, zip(*top_n_bigrams))
ax = sns.barplot(x=y, y=x)
ax.set(xlabel='빈도 수', ylabel='3gram 형태소', title='Answer 3-gram 통계(형태소)')
# Out:
# [Text(0.5, 0, '빈도 수'),
#  Text(0, 0.5, '3gram 형태소'),
#  Text(0.5, 1.0, 'Answer 3-gram 통계(형태소)')]

# %% [markdown]
# ## Question / Answer 개체명 분석

# %% [markdown]
# ### 개체명 전처리

# %%
# 1회 최대 글자수 1만개
# 문장 당 평균 10~20 글자
# 대충 50글자라 했을 때, 200개를 한 묶음
# 전체 데이터 수 11823*2=23646개
# Question / Answer 따로 한다면 200*60=12000 -> 200개를 한 묶음으로 60묶음
print(len(csvdataset))
q_bundles, a_bundles = [], []

#bundle의 순서: 0~199, 200~399, ... 
for i in range(60):
    if i == 59: 
        q_bundles.append('\n'.join(csvdataset["Q"][i*200:]))
        a_bundles.append('\n'.join(csvdataset["A"][i*200:]))
        break 
    else: 
        q_bundles.append('\n'.join(csvdataset["Q"][i*200:(i+1)*200]))
        a_bundles.append('\n'.join(csvdataset["A"][i*200:(i+1)*200]))
# Out:
# 11823

# %%
import urllib3
import json
from tqdm import tqdm

openApiURL = "http://aiopen.etri.re.kr:8000/WiseNLU_spoken"
accessKey = "INPUT YOUR API KEY"
analysisCode = "ner"

q_ne, a_ne = [], []
q_err, a_err = [], []

for i, text in enumerate(tqdm(q_bundles)):
    requestJson = {
        "access_key": accessKey,
        "argument": {
            "text": text,
            "analysis_code": analysisCode
        }
    }
    http = urllib3.PoolManager()
    response = http.request("POST", openApiURL, headers={"content-Type": "application/json; charset=UTF-8"}, body=json.dumps(requestJson))
    dict_temp = json.loads(str(response.data, "utf-8"))
    try:
        for d in dict_temp['return_object']['sentence']:
            q_ne += d['NE']
    except:
        q_err += dict_temp
        
for i, text in enumerate(tqdm(a_bundles)):
    requestJson = {
        "access_key": accessKey,
        "argument": {
            "text": text,
            "analysis_code": analysisCode
        }
    }
    http = urllib3.PoolManager()
    response = http.request("POST", openApiURL, headers={"content-Type": "application/json; charset=UTF-8"}, body=json.dumps(requestJson))
    dict_temp = json.loads(str(response.data, "utf-8"))
    try:
        for d in dict_temp['return_object']['sentence']:
            a_ne += d['NE']
    except:
        a_err += dict_temp
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 60/60 [00:50<00:00,  1.18it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 60/60 [00:56<00:00,  1.07it/s]

# %%
qne_dict, ane_dict = [], []
qne_names, ane_names = [], []
qne_tags, ane_tags = [], []
qne_txt, ane_txt = '', '' 
for n in q_ne: 
    qne_txt += n['text'] + '\t' + n['type'] + '\n' 
    qne_dict.append((n['text'], n['type'])) 
    qne_names += [n['text']] 
    qne_tags += [n['type']]
    
for n in a_ne: 
    ane_txt += n['text'] + '\t' + n['type'] + '\n' 
    ane_dict.append((n['text'], n['type'])) 
    ane_names += [n['text']] 
    ane_tags += [n['type']]

# %% [markdown]
# ### 개체명 분포

# %%
count = collections.Counter(qne_names)
most = count.most_common()

x, y = [], []
for word, count in most[:40]:
    x.append(word)
    y.append(count)
    
plt.rcParams['font.family'] = 'NanumGothic'
plt.figure(figsize=(10, 10))
ax = sns.barplot(x=y, y=x)
ax.set(title='Question 개체명에 따른 빈도 수', xlabel='빈도 수', ylabel='개체명')
# Out:
# [Text(0.5, 1.0, 'Question 개체명에 따른 빈도 수'),
#  Text(0.5, 0, '빈도 수'),
#  Text(0, 0.5, '개체명')]

# %%
count = collections.Counter(ane_names)
most = count.most_common()

x, y = [], []
for word, count in most[:40]:
    x.append(word)
    y.append(count)
    
plt.rcParams['font.family'] = 'NanumGothic'
plt.figure(figsize=(10, 10))
ax = sns.barplot(x=y, y=x)
ax.set(title='Answer 개체명에 따른 빈도 수', xlabel='빈도 수', ylabel='개체명')
# Out:
# [Text(0.5, 1.0, 'Answer 개체명에 따른 빈도 수'),
#  Text(0.5, 0, '빈도 수'),
#  Text(0, 0.5, '개체명')]

# %% [markdown]
# ### 개체명 태그 분포

# %%
count = collections.Counter(qne_tags)
most = count.most_common()

x, y = [], []
for word, count in most[:40]:
    x.append(word)
    y.append(count)
    
plt.rcParams['font.family'] = 'NanumGothic'
plt.figure(figsize=[10, 10])
ax = sns.barplot(x=y, y=x)
ax.set(title='Question 개체명 태그 분포', xlabel='빈도 수', ylabel='개체명 태그')
# Out:
# [Text(0.5, 1.0, 'Question 개체명 태그 분포'),
#  Text(0.5, 0, '빈도 수'),
#  Text(0, 0.5, '개체명 태그')]

# %%
count = collections.Counter(ane_tags)
most = count.most_common()

x, y = [], []
for word, count in most[:40]:
    x.append(word)
    y.append(count)
    
plt.rcParams['font.family'] = 'NanumGothic'
plt.figure(figsize=[10, 10])
ax = sns.barplot(x=y, y=x)
ax.set(title='Answer 개체명 태그 분포', xlabel='빈도 수', ylabel='개체명 태그')
# Out:
# [Text(0.5, 1.0, 'Answer 개체명 태그 분포'),
#  Text(0.5, 0, '빈도 수'),
#  Text(0, 0.5, '개체명 태그')]

# %% [markdown]
# ### 개체명 CV_RELATION 분포

# %%
q_cv_relation = []
for i, n in enumerate(qne_names):
    if qne_tags[i] == 'CV_RELATION':
        q_cv_relation.append(n)
count = collections.Counter(q_cv_relation)
most = count.most_common()

x, y = [], []
for word, count in most[:40]:
    x.append(word)
    y.append(count)
    
plt.rcParams['font.family'] = 'NanumGothic'
plt.figure(figsize=(10, 10))
ax = sns.barplot(x=y, y=x)
ax.set(title='Question 최다 개체명에 따른 빈도', xlabel='빈도 수', ylabel='개체명(CV_RELATION)')
# Out:
# [Text(0.5, 1.0, 'Question 최다 개체명에 따른 빈도'),
#  Text(0.5, 0, '빈도 수'),
#  Text(0, 0.5, '개체명(CV_RELATION)')]

# %%
a_cv_relation = []
for i, n in enumerate(ane_names):
    if ane_tags[i] == 'CV_RELATION':
        a_cv_relation.append(n)
count = collections.Counter(a_cv_relation)
most = count.most_common()

x, y = [], []
for word, count in most[:40]:
    x.append(word)
    y.append(count)
    
plt.rcParams['font.family'] = 'NanumGothic'
plt.figure(figsize=(10, 10))
ax = sns.barplot(x=y, y=x)
ax.set(title='Answer 최다 개체명에 따른 빈도', xlabel='빈도 수', ylabel='개체명(CV_RELATION)')
# Out:
# [Text(0.5, 1.0, 'Answer 최다 개체명에 따른 빈도'),
#  Text(0.5, 0, '빈도 수'),
#  Text(0, 0.5, '개체명(CV_RELATION)')]
